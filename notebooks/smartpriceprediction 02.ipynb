# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/smartproductpricing/EcomProductPricing/dataset/train.csv
# /kaggle/input/smartproductpricing/EcomProductPricing/dataset/test.csv
# /kaggle/input/smartproductpricing/EcomProductPricing/src/text_features.py
# /kaggle/input/smartproductpricing/EcomProductPricing/src/image_features.py
# /kaggle/input/smartproductpricing/EcomProductPricing/src/utils.py
# /kaggle/input/smartproductpricing/EcomProductPricing/src/train_model.py

# %%
# !pip install -q transformers==4.41.2 sentence-transformers==2.2.2 peft==0.10.0 huggingface_hub==0.23.4
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 97.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 25.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 93.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.0 MB/s eta 0:00:00
#   Building wheel for sentence-transformers (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.1.1 requires huggingface-hub>=0.24.0, but you have huggingface-hub 0.23.4 which is incompatible.
# datasets 4.1.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# diffusers 0.34.0 requires huggingface-hub>=0.27.0, but you have huggingface-hub 0.23.4 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires huggingface-hub>=0.28.1, but you have huggingface-hub 0.23.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.0a1 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.

# %%
try:
    template_path = hf_hub_download(
        repo_id="sentence-transformers/all-MiniLM-L6-v2",
        filename="additional_chat_templates"
    )
except Exception as e:
    template_path = None

# %%
# !pip uninstall -y tensorflow tensorflow-gpu keras keras-nightly keras-preprocessing keras-utils && pip install -q tensorflow==2.15.0
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# WARNING: Skipping tensorflow-gpu as it is not installed.
# Found existing installation: keras 3.8.0
# Uninstalling keras-3.8.0:
#   Successfully uninstalled keras-3.8.0
# WARNING: Skipping keras-nightly as it is not installed.
# WARNING: Skipping keras-preprocessing as it is not installed.
# WARNING: Skipping keras-utils as it is not installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 MB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 64.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 91.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 26.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 4.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.5.2 requires ml_dtypes>=0.4.0, but you have ml-dtypes 0.2.0 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.15.0 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.15.0 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.15.0 which is incompatible.
# tensorstore 0.1.74 requires ml_dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.

# %%
# !nvidia-smi
# Out:
# Fri Oct 17 19:55:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   32C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

print("TensorFlow version:", tf.__version__)
print(device_lib.list_local_devices())
# Out:
# 2025-10-17 19:55:30.625838: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-17 19:55:30.625904: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-17 19:55:30.627533: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TensorFlow version: 2.15.0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4903419623189652224
# xla_global_id: -1
# ]

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
import sys, os

sys.path.append('/kaggle/input/smartproductpricing/EcomProductPricing/src')

DATASET_FOLDER = '/kaggle/input/smartproductpricing/EcomProductPricing/dataset'
TRAIN_DATA_PATH = os.path.join(DATASET_FOLDER, 'train.csv')
TEST_DATA_PATH = os.path.join(DATASET_FOLDER, 'test.csv')
OUTPUT_PATH = '/kaggle/working/test_out.csv'

# %%
# !python /kaggle/input/smartproductpricing/EcomProductPricing/src/train_model.py
# Out:
# 2025-10-17 19:55:49.379098: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-17 19:55:49.379156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-17 19:55:49.380671: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🚀 Loading Training and Test Data...
#
# 📝 Extracting Text Features...
# 🚀 Starting Optimized Enhanced Text Feature Engineering...
# 📊 Extracting IPQ features...
#    ✓ IPQ extraction complete. Found 75000 valid IPQ values
# 🏷️  Extracting brands and categories...
# 🔹 Running optimized semantic clustering...
# .gitattributes: 1.23kB [00:00, 4.84MB/s]
# config.json: 100%|█████████████████████████████| 190/190 [00:00<00:00, 1.45MB/s]
# README.md: 10.5kB [00:00, 41.3MB/s]
# config.json: 100%|█████████████████████████████| 612/612 [00:00<00:00, 5.30MB/s]
# config_sentence_transformers.json: 100%|███████| 116/116 [00:00<00:00, 1.08MB/s]
# data_config.json: 39.3kB [00:00, 103MB/s]
# model.safetensors: 100%|████████████████████| 90.9M/90.9M [00:00<00:00, 265MB/s]
# model.onnx: 100%|███████████████████████████| 90.4M/90.4M [00:00<00:00, 313MB/s]
# model_O1.onnx: 100%|████████████████████████| 90.4M/90.4M [00:00<00:00, 307MB/s]
# model_O2.onnx: 100%|████████████████████████| 90.3M/90.3M [00:00<00:00, 314MB/s]
# model_O3.onnx: 100%|████████████████████████| 90.3M/90.3M [00:00<00:00, 295MB/s]
# model_O4.onnx: 100%|████████████████████████| 45.2M/45.2M [00:00<00:00, 265MB/s]
# model_qint8_arm64.onnx: 100%|███████████████| 23.0M/23.0M [00:00<00:00, 235MB/s]
# model_qint8_avx512.onnx: 100%|██████████████| 23.0M/23.0M [00:00<00:00, 266MB/s]
# model_qint8_avx512_vnni.onnx: 100%|█████████| 23.0M/23.0M [00:00<00:00, 267MB/s]
# model_quint8_avx2.onnx: 100%|███████████████| 23.0M/23.0M [00:00<00:00, 235MB/s]
# openvino_model.bin: 100%|███████████████████| 90.3M/90.3M [00:00<00:00, 316MB/s]
# openvino_model.xml: 211kB [00:00, 267MB/s]
# openvino_model_qint8_quantized.bin: 100%|███| 22.9M/22.9M [00:00<00:00, 246MB/s]
# openvino_model_qint8_quantized.xml: 368kB [00:00, 163MB/s]
# pytorch_model.bin: 100%|████████████████████| 90.9M/90.9M [00:00<00:00, 288MB/s]
# sentence_bert_config.json: 100%|██████████████| 53.0/53.0 [00:00<00:00, 494kB/s]
# special_tokens_map.json: 100%|██████████████████| 112/112 [00:00<00:00, 995kB/s]
# tokenizer.json: 466kB [00:00, 38.2MB/s]
# tokenizer_config.json: 100%|███████████████████| 350/350 [00:00<00:00, 2.95MB/s]
# train_script.py: 13.2kB [00:00, 53.2MB/s]
# vocab.txt: 232kB [00:00, 114MB/s]
# modules.json: 100%|████████████████████████████| 349/349 [00:00<00:00, 4.98MB/s]
# Batches: 100%|████████████████████████████████| 147/147 [02:22<00:00,  1.03it/s]
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    ✓ Created 50 clusters with 75000 products
# 💲 Creating price range features...
#    ✓ Added cluster price statistics
# 💰 Extracting price indicators...
# 🔢 Extracting numerical specifications...
# 📝 Calculating text richness metrics...
#    ✓ Extracted 23100 products with premium indicators
#    ✓ Found 28556 products with bulk indicators
# 🧹 Enhanced text cleaning and optimized TF-IDF...
#    ✓ TF-IDF fitted with 800 features
# 🏗️  Creating categorical features...
# 🔗 Combining all features...
# ✅ Optimized feature engineering complete!
#    📏 Final feature matrix shape: (75000, 899)
#    📊 TF-IDF features: 800
#    🔢 Numerical features: 22
#    🏷️  Categorical features: 77
#    💾 Memory usage: 31.2 MB
# 🚀 Starting Optimized Enhanced Text Feature Engineering...
# 📊 Extracting IPQ features...
#    ✓ IPQ extraction complete. Found 75000 valid IPQ values
# 🏷️  Extracting brands and categories...
# 🔹 Running optimized semantic clustering...
# Batches: 100%|████████████████████████████████| 147/147 [02:18<00:00,  1.06it/s]
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    ✓ Created 50 clusters with 75000 products
# 💰 Extracting price indicators...
# 🔢 Extracting numerical specifications...
# 📝 Calculating text richness metrics...
#    ✓ Extracted 23027 products with premium indicators
#    ✓ Found 28445 products with bulk indicators
# 🧹 Enhanced text cleaning and optimized TF-IDF...
#    ✓ TF-IDF transformed with 800 features
# 🏗️  Creating categorical features...
# 🔗 Combining all features...
# ✅ Optimized feature engineering complete!
#    📏 Final feature matrix shape: (75000, 896)
#    📊 TF-IDF features: 800
#    🔢 Numerical features: 19
#    🏷️  Categorical features: 77
#    💾 Memory usage: 29.6 MB
#
# 🖼️ Extracting Image Features...
# Starting Comprehensive Image Feature Extraction...
# Traditional Features: 100%|███████████| 75000/75000 [00:00<00:00, 108656.41it/s]
# ✅ Traditional features extracted: (75000, 22)
# 🔥 Initializing EFFICIENTNET for feature extraction...
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# Deep Features: 100%|████████████████████████| 2344/2344 [48:59<00:00,  1.25s/it]
# ✅ Deep feature extraction complete. Shape: (75000, 1280)
# ✅ Comprehensive features ready. Total features: 1302
# Starting Comprehensive Image Feature Extraction...
# Traditional Features: 100%|███████████| 75000/75000 [00:00<00:00, 110755.48it/s]
# ✅ Traditional features extracted: (75000, 22)
# 🔥 Initializing RESNET50 for feature extraction...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Deep Features: 100%|██████████████████████| 2344/2344 [1:30:52<00:00,  2.33s/it]
# ✅ Deep feature extraction complete. Shape: (75000, 2048)
# ✅ Comprehensive features ready. Total features: 2070
# ✅ Saved image features: X_train_image.npy, X_test_image.npy
#
# 🔗 Combining Text and Image Features...
# ⚠️ Feature mismatch detected! Aligning test features (2198) → train (2201)
# ✅ After alignment: train=(75000, 2201), test=(75000, 2201)
# Final Train Feature Shape: (75000, 2201)
# Final Test Feature Shape: (75000, 2201)
#
# 💾 Saving final combined features...
# ✅ Saved: train_features.npy, test_features.npy
#
#  Training LightGBM Regressor...
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 203919
# [LightGBM] [Info] Number of data points in the train set: 67500, number of used features: 891
# [LightGBM] [Info] Using requested OpenCL platform 0 device 0
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 16 dense feature groups (1.03 MB) transferred to GPU in 0.003470 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 2.708050
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's l1: 0.539454
#
# 🔮 Generating Predictions...
# /usr/local/lib/python3.11/dist-packages/lightgbm/basic.py:1238: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning("Converting data to scipy sparse matrix.")
#
# ✅ Training Set SMAPE Score: 42.2488%
#
#  Predictions saved to /kaggle/working/test_out.csv
# Total predictions: 75000
# Price range: $0.34 - $74.39
# Sample predictions:
#    sample_id      price
# 0     100179   8.494911
# 1     245611  10.529513
# 2     146263  16.354969
# 3      95658   9.758280
# 4      36806  10.714551
#
#  Training and prediction pipeline completed successfully!
#  Ready for submission to ML Challenge!
